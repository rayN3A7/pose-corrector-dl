# %%
print("Hello, Poses! Your DL journey begins.")
import tensorflow as tf
import mediapipe as mp
print(f"TensorFlow: {tf.__version__}, MediaPipe: {mp.__version__}")
# Out:
# Hello, Poses! Your DL journey begins.
# TensorFlow: 2.19.1, MediaPipe: 0.10.21
